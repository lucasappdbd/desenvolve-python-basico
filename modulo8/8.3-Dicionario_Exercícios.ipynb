# %% [markdown]
# # Dicionários
#
# ## Aula 8.3

# %% [markdown]
# ### Q1.
#
# Escreva uma função em Python chamada ```contagem_caracteres``` que recebe uma string como parâmetro e retorna um dicionário onde as chaves são os caracteres presentes na string e os valores são a contagem de cada caractere.

# %%
# Implemente aqui a função contagem_caracteres
def contagem_caracteres(frase):
    dicionario = {}
    for letra in frase:
        letra = letra.lower()
        dicionario[letra] = dicionario.get(letra, 0) + 1
    return dicionario

# %%
# Exemplo de uso:
frase = "python programming"
resultado = contagem_caracteres(frase)
print(resultado)
# Out:
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 2, ' ': 1, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 1}

# %% [markdown]
# ### Q2.
#
# Baixe o arquivo contendo o roteiro do filme brasileiro "Estômago" e salve em seu computador com o nome "estomago.txt".
#
# https://aplauso.imprensaoficial.com.br/edicoes/12.0.813.502/12.0.813.502.txt
#
# - Escreva um script python que abre o arquivo de texto e cria um dicionário contando a quantidade de vezes que cada palavra aparece no texto.
# - Em seguida ordene o dicionário de forma decrescente pelos valores. Dessa maneira ele irá apresentar as palavras mais frequentes no início.
# - Apresente na tela o dicionário ordenado

# %%
# Implemente aqui sua solução
f = open('estomago.txt', 'r')
linhas = [linha.split(" ") for linha in f.readlines()]
f.close()

dicionario_cont = {}

for linha in linhas:
    for palavra in linha:
        palavra = palavra.lower()
        dicionario_cont[palavra] = dicionario_cont.get(palavra, 0) + 1

print(sorted(dicionario_cont.items(), key = lambda item: item[1], reverse = True))
# Out:
# [('', 3852), ('\n', 1801), ('de', 1270), ('e', 932), ('o', 884), ('a', 749), ('que', 646), ('nonato', 520), ('um', 472), ('do', 404), ('com', 327), ('é', 314), ('da', 291), ('uma', 285), ('no', 240), ('não', 237), ('na', 234), ('em', 233), ('se', 224), ('para', 220), ('–', 210), ('os', 186), ('giovanni', 139), ('mas', 138), ('as', 121), ('por', 118), ('eu', 113), ('mais', 98), ('pra', 98), ('íria', 98), ('ao', 97), ('seu', 96), ('tem', 93), ('como', 92), ('tá', 88), ('bujiú', 84), ('está', 81), ('ele', 80), ('zulmiro', 77), ('vai', 75), ('foi', 73), ('você', 73), ('dos', 72), ('nonato,', 70), ('int.', 66), ('cena', 63), ('faz', 63), ('até', 62), ('cozinha', 59), ('bem', 58), ('nonato.', 58), ('já', 56), ('pouco', 56), ('roteiro', 54), ('muito', 53), ('sobre', 51), ('olha', 47), ('era', 46), ('tudo', 46), ('lá', 46), ('aqui', 46), ('são', 45), ('me', 45), ('fazer', 44), ('cela', 44), ('esse', 43), ('dá', 43), ('quando', 42), ('1', 42), ('dentro', 41), ('só', 41), ('à', 40), ('das', 40), ('esta', 40), ('meio', 39), ('isso', 39), ('filme', 38), ('também', 38), ('ser', 38), ('ou', 37), ('enquanto', 36), ('alho', 36), ('estômago', 35), ('pela', 35), ('então', 35), ('cozinha.', 35), ('coisa', 34), ('num', 34), ('nem', 34), ('mesmo', 33), ('pelo', 33), ('sua', 33), ('dia', 33), ('numa', 33), ('-noite', 33), ('nota:', 33), ('ela', 32), ('restaurante', 32), ('marcos', 31), ('onde', 31), ('depois', 31), ('câmera', 31), ('2', 31), ('entre', 30), ('queijo', 30), ('vagnão', 30), ('sem', 29), ('coisas', 29), ('prato', 29), ('lado', 29), ('alguns', 28), ('abre', 28), ('cinema', 27), ('ter', 27), ('pode', 27), ('cara', 27), ('essa', 27), ('carne', 27), ('panela', 27), ('sal', 27), ('ficar', 26), ('pro', 26), ('outro', 26), ('e,', 26), ('algumas', 26), ('porta', 26), ('grande', 25), ('direção', 25), ('ainda', 25), ('este', 25), ('estão', 25), ('raimundo', 25), ('pega', 25), ('começa', 25), ('joga', 25), ('todos', 24), ('ah,', 24), ('mulher', 24), ('carcereiro', 24), ('sendo', 23), ('tempo', 23), ('bom', 23), ('homens', 23), ('cê', 23), ('não,', 23), ('suas', 22), ('deixa', 22), ('boteco', 22), ('vou', 22), ('beliche', 22), ('jorge', 21), ('antes', 21), ('quem', 21), ('melhor', 21), ('primeiro', 21), ('bujiú,', 21), ('macarrão', 21), ('fica', 21), ('apanha', 21), ('sai', 21), ('coloca', 21), ('1/2', 21), ('porque', 20), ('paulo', 20), ('nos', 20), ('agora', 20), ('gente', 20), ('comida', 20), ('comer', 20), ('-dia', 20), ('azeite', 20), ('íria,', 20), ('maria', 20), ('colheres', 20), ('eles', 19), ('nas', 19), ('íria.', 19), ('ver', 19), ('parece', 19), ('vão', 19), ('prá', 19), ('te', 19), ('(v.o.)', 19), ('cláudia', 18), ('história', 18), ('tinha', 18), ('aí', 18), ('arte', 18), ('água', 18), ('garrafa', 18), ('cebola', 18), ('nome', 17), ('volta', 17), ('dois', 17), ('sabe', 17), ('vida', 17), ('ponto', 17), ('entra', 17), ('tou', 17), ('mesa', 17), ('coloque', 17), ('lusa', 16), ('quanto', 16), ('cada', 16), ('atrás', 16), ('hora', 16), ('filme.', 16), ('assim', 16), ('aquele', 16), ('outros', 16), ('tira', 16), ('come', 16), ('não.', 16), ('francesco', 16), ('ponha', 16), ('carlos', 16), ('seus', 15), ('quase', 15), ('vem', 15), ('além', 15), ('bastante', 15), ('durante', 15), ('alecrim,', 15), ('boa', 15), ('peixe', 15), ('fala', 15), ('uns', 15), ('merda', 15), ('copo', 15), ('farinha', 15), ('lino', 15), ('etecetera', 15), ('esses', 14), ('pois', 14), ('teatro', 14), ('desde', 14), ('menos', 14), ('bujiú.', 14), ('isso,', 14), ('filmes', 14), ('luiz', 14), ('tão', 14), ('mas,', 14), ('mão', 14), ('homem', 14), ('duas', 14), ('umas', 14), ('noite', 14), ('perto', 14), ('dentes', 14), ('cima', 14), ('aproxima', 14), ('molho', 14), ('quer', 14), ('aqui,', 14), ('pedaço', 14), ('pimenta', 14), ('coleção', 13), ('é?', 13), ('estômago,', 13), ('fazendo', 13), ('minha', 13), ('outra', 13), ('cela.', 13), ('gosto', 13), ('final', 13), ('passa', 13), ('rosto', 13), ('leitão', 13), ('deixe', 13), ('3', 13), ('brasil', 13), ('versão', 12), ('prime ...

# %% [markdown]
# ### Q3.
#
# Crie uma função chamada ```mesclar_dicionarios``` que recebe dois dicionários como parâmetros e retorna um novo dicionário contendo a fusão dos dois. Se houver chaves comuns, o maior valor deve prevalecer.

# %%
# Implemente aqui a função mesclar_dicionarios
def mesclar_dicionarios(dicionario1, dicionario2):
    dicionario_mesclado = dicionario1
    for chave, valor in dicionario2.items():
        if chave in dicionario_mesclado:
            dicionario_mesclado[chave] = max(dicionario_mesclado[chave], valor)
        else:
            dicionario_mesclado[chave] = valor
    return dicionario_mesclado

# %%
# Exemplo de uso:
dicionario1 = {'a': 1, 'b': 2, 'c': 3}
dicionario2 = {'b': 4, 'd': 5}
resultado = mesclar_dicionarios(dicionario1, dicionario2)
print(resultado)
# Saída esperada: {'a': 1, 'b': 4, 'c': 3, 'd': 5}
# Out:
# {'a': 1, 'b': 4, 'c': 3, 'd': 5}

# %% [markdown]
# ### Q4.
#
# Desenvolva uma função em Python chamada ```filtrar_dicionario``` que recebe um dicionário e uma lista de chaves como parâmetros e retorna um novo dicionário contendo apenas as chaves que estão presentes na lista.

# %%
# Implemente aqui a função filtrar_dicionario
def filtrar_dicionario(dados, chaves_filtradas):
    dicionario_filtrado = {chave: dados[chave] for chave in chaves_filtradas if chave in dados}
    return dicionario_filtrado

# %%
# Exemplo de uso:
dados = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
chaves_filtradas = ['a', 'c', 'e']
resultado = filtrar_dicionario(dados, chaves_filtradas)
print(resultado)
# Saída esperada: {'a': 1, 'c': 3, 'e': 5}
# Out:
# {'a': 1, 'c': 3, 'e': 5}

# %% [markdown]
# ### Q5.
#
# Você está responsável por analisar os resultados de uma votação. Cada voto é representado por um dicionário com o nome do candidato e a quantidade de votos que recebeu em uma determinada sessão eleitoral. Escreva uma função chamada ```resultado_votacao``` que recebe uma lista de dicionários de votos e retorna um dicionário onde as chaves são os nomes dos candidatos, e os valores são tuplas ```(total, percentual)``` com o total de votos recebidos por cada candidato e o percentual em relação à soma total de votos em todos os candidatos.

# %%
# Implemente aqui a função resultado_votacao
def resultado_votacao(votos):
    totais_votos = {}
    for voto in votos:
        for candidato, quantidade in voto.items():
            if candidato not in totais_votos:
                totais_votos[candidato] = 0
            totais_votos[candidato] += quantidade

    total_geral = sum(totais_votos.values())
    resultado = {}

    for candidato, total in totais_votos.items():
        percentual = (total / total_geral) * 100
        resultado[candidato] = (total, round(percentual, 2))
    return resultado

# %%
# Exemplo de uso:
votos = [
    {'candidato_A': 120, 'candidato_B': 85, 'candidato_C': 90},
    {'candidato_A': 110, 'candidato_B': 95, 'candidato_C': 80},
    {'candidato_A': 130, 'candidato_B': 78, 'candidato_C': 105},
]
resultado = resultado_votacao(votos)
print(resultado)  # Saída esperada: {'candidato_A': (360, 40.31), 'candidato_B': (258, 28.89), 
                                ###  'candidato_C': (275, 30.79)}
# Out:
# {'candidato_A': (360, 40.31), 'candidato_B': (258, 28.89), 'candidato_C': (275, 30.8)}
